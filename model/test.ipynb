# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path

# %%
df=pd.read_pickle(Path('C:/Users/Victor/Desktop/PIR/data/Ch022.pkl'))
df
# Out:
#              1.088830  1.136030  1.185275  1.236655  1.290265  1.346200  \
# 1998.496576       0.0    1.0430     62.33    110.40    113.40    133.20
# 1998.497946       0.0    0.7059     32.07     73.89    108.00    108.40
# 1998.499316       0.0    1.6500     62.49    108.00    105.20    139.70
# 1998.500686       0.0    0.6818     49.14     72.12     94.89    102.20
# 1998.502056       0.0    1.5040     42.24     88.89    150.90    155.40
# ...               ...       ...       ...       ...       ...       ...
# 2004.994956       0.0    0.8059     36.89     83.40    121.90    144.30
# 2004.996326       0.0    0.5439     24.04     37.64     30.80     44.74
# 2004.997696       0.0    0.5592     32.74     73.08    119.70    123.80
# 2004.999066       0.0    1.3600     41.88     69.97     71.37     78.48
# 2004.999875      -1.0   -1.0000     53.15     65.15     85.29    155.40
#
#              1.404560  1.465450  1.528980  1.595265  ...  5.461530  5.698290  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
df=pd.read_pickle(Path('C:/Users/Victor/Desktop/PIR/data/Ch022.pkl'))
scaler= StandardScaler()
df_123[df_123 <= 0] = 0.01
df[:]=scaler.fit_transform(df.values)
df[:]=scaler.inverse_transform(df.values)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-282a63feddf6> in <module>
#       2 df=pd.read_pickle(Path('C:/Users/Victor/Desktop/PIR/data/Ch022.pkl'))
#       3 scaler= StandardScaler()
# ----> 4 df_123[df_123 <= 0] = 0.01
#       5 df[:]=scaler.fit_transform(df.values)
#       6 df[:]=scaler.inverse_transform(df.values)
#
# NameError: name 'df_123' is not defined

# %%
p=24
plt.figure()
plt.plot(df.index, df.iloc[:,p])
plt.show()

# %%
print(df[df.columns[p]])
# Out:
# 1998.496576    0.058675
# 1998.497946   -0.040602
# 1998.499316    0.059205
# 1998.500686   -0.045592
# 1998.502056    0.009089
#                  ...
# 2004.994956    0.368926
# 2004.996326    0.845347
# 2004.997696    0.587228
# 2004.999066    0.512585
# 2004.999875    0.047207
# Name: 3.015005, Length: 4722, dtype: float64
